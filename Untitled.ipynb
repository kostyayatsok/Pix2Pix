▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:
# wandb: Run summary:
# wandb:   d_fake_loss_train 0.13145
# wandb:     d_fake_loss_val 0.04
# wandb:        d_loss_train 0.1232
# wandb:          d_loss_val 0.12814
# wandb:   d_real_loss_train 0.11496
# wandb:     d_real_loss_val 0.21628
# wandb:               epoch 400
# wandb:             fid_val 225.61393
# wandb:   g_fake_loss_train 4.31714
# wandb:     g_fake_loss_val 5.07515
# wandb:     g_l1_loss_train 0.21244
# wandb:       g_l1_loss_val 0.36626
# wandb:        g_loss_train 25.56105
# wandb:          g_loss_val 41.70126
# wandb:                step 160000
# wandb:
# wandb: Synced 5 W&B file(s), 6400 media file(s), 400 artifact file(s) and 0 other file(s)
# wandb: Synced polished-haze-95: https://wandb.ai/kostyayatsok/Pix2Pix/runs/2aoy5xvl
# wandb: Find logs at: ./wandb/run-20211214_230323-2aoy5xvl/logs/debug.log
# wandb:

# %%
#!g1.1:bash
python3 main.py --mode 'test' --frm './facades/test/' --to './predictions_test/'
# Out:
# Created generator with 54413958 parameters
# Created discriminator with 1715456 parameters
# FID: 241.5124595211794

# %%
import matplotlib.pyplot as plt
import glob
from PIL import Image
from random import shuffle
plt.figure(figsize=(10, 10))
paths = glob.glob('predictions_val/*.jpg')
shuffle(paths)
for i, img_p in enumerate(paths):
    plt.subplot(4, 4, i + 1)
    img = Image.open(img_p)
    plt.imshow(img)
    plt.axis('off')
    if i == 15:
        break
plt.subplots_adjust(wspace=.05, hspace=.05)
plt.save('example.jpg')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-7e058cf2bb56> in <module>
#      14         break
#      15 plt.subplots_adjust(wspace=.05, hspace=.05)
# ---> 16 plt.imsave('example.jpg')
#      17 plt.show()
#      18 #
#
# TypeError: imsave() missing 1 required positional argument: 'arr'

# %%
# !git add .
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	new file:   Untitled.ipynb
# 	modified:   data.py
# 	modified:   loss.py
# 	modified:   main.py
# 	modified:   model.py
# 	modified:   test.py
# 	modified:   train.py

# %%
# !git reset *.ipynb

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	modified:   data.py
# 	modified:   loss.py
# 	modified:   main.py
# 	modified:   model.py
# 	modified:   test.py
# 	modified:   train.py
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	Untitled.ipynb

# %%
# !git commit -m "+- okay v"
# Out:
# [main ba786f9] +- okay v
#  6 files changed, 53 insertions(+), 38 deletions(-)

# %%
# !git push origin main
# Out:
# Counting objects: 8, done.
# Delta compression using up to 4 threads.
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (8/8), 1.49 KiB | 1.49 MiB/s, done.
# Total 8 (delta 6), reused 0 (delta 0)
# remote: Resolving deltas: 100% (6/6), completed with 6 local objects.
# To https://github.com/kostyayatsok/Pix2Pix.git
#    85f28f8..ba786f9  main -> main
